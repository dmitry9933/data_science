# %%
import pandas as pd
import seaborn
from matplotlib import pyplot as plt
import os

# %%
data_dir = "./data/"
data = []
for file in os.listdir(data_dir):
    data_raw = pd.read_excel(data_dir + file, skiprows=4)
    data_raw.columns = [column.lower().replace("\n", "").replace(" ", "_").replace("-", "_").strip() for column in
                        data_raw.columns]
    data.append(data_raw)

data = pd.concat(data)
print(data.columns)
# Out:
# Index(['borough', 'neighborhood', 'building_class_category',
#        'tax_class_at_present', 'block', 'lot', 'ease_ment',
#        'building_class_at_present', 'address', 'apartmentnumber', 'zip_code',
#        'residential_units', 'commercial_units', 'total_units',
#        'land_square_feet', 'gross_square_feet', 'year_built',
#        'tax_class_at_time_of_sale', 'building_class_at_time_of_sale',
#        'saleprice', 'sale_date'],
#       dtype='object')

# %%
def get_district_by_borough(borough):
    if borough == 1:
        return "Manhattan"
    elif borough == 2:
        return "Bronx"
    elif borough == 3:
        return "Brooklyn"
    elif borough == 4:
        return "Queens"
    elif borough == 5:
        return "Staten Island"


data.insert(1, "district", [get_district_by_borough(a) for a in data.borough])
data
# Out:
#        borough district               neighborhood  \
# 0            2    Bronx  BATHGATE
# 1            2    Bronx  BATHGATE
# 2            2    Bronx  BATHGATE
# 3            2    Bronx  BATHGATE
# 4            2    Bronx  BATHGATE
# ...        ...      ...                        ...
# 23578        4   Queens  WOODSIDE
# 23579        4   Queens  WOODSIDE
# 23580        4   Queens  WOODSIDE
# 23581        4   Queens  WOODSIDE
# 23582        4   Queens  WOODSIDE
#
#                             building_class_category tax_class_at_present  \
# 0      01  ONE FAMILY HOMES                                            1
# 1      01  ONE FAMILY HOMES                                            1
# 2      01  ONE FAMILY HOMES                                            1
# 3      01  ONE FAMILY HOMES                                            1
# 4      02  TWO FAMILY HOMES                                            1
# ...                                             ...                  ...
# 23578  31  COMMERCIAL VACANT LAND                                      4
# 23579  31  COMMERCIAL VACANT LAND                                      4
# 23580  37  RELIGIOUS FACILITIES                                        4
# 23581  37  RELIGIOUS FACILITIES                                        4
# 23582  37  RELIGIOUS FACILITIES                                        4
#
#        block  lot ease_ment building_class_at_present  \
# 0       3028   25                                  A5
# 1       3039   28                                  A1
# 2       3046   39                                  A1
# 3       3046   52                                  A1
# 4       2900   61                                  S2
# ...      ...  ...       ...                       ...
# 23578   1186   80                                  V1
# 23579   1342   38                                  V1
# 23580   1213    6                                  M1
# 23581   1321   10                                  M1
# 23582   1321   10                                  M1
#
#                                          address  ... residential_units  \
# 0      412 EAST 179TH STREET                      ...                 1
# 1      2329 WASHINGTON AVENUE                     ...                 1
# 2      2075 BATHGATE AVENUE                       ...                 1
# 3      2047 BATHGATE AVENUE                       ...                 1
# 4      406 EAST TREMONT AVENUE                    ...                 2
# ...                                          ...  ...               ...
# 23578  64TH   STREET                              ...                 0
# 23579  65-15 QUEENS BOULEVARD                     ...                 0
# 23580  58-11 39TH   AVENUE                        ...                 0
# 23581  43-25 52ND   STREET                        ...                 0
# 23582  43-25 52ND   STREET                        ...                 0
#
#        commercial_units  total_units  land_square_feet  gross_square_feet  \
# 0                     0            1              1842               2048
# 1                     0            1              1103               1290
# 2                     0            1              1986               1344
# 3                     0            1              2329               1431
# 4                     1            3              1855               4452
# ...                 ...          ...               ...                ...
# 23578                 0            0              1707                  0
# 23579                 0            0              3000                  0
# 23580                 1            1              2523               3000
# 23581                 1            1              5000              20000
# 23582                 1            1              5000              20000
#
#        year_built  tax_class_at_time_of_sale  building_class_at_time_of_sale  \
# 0            1901                          1                              A5
# 1            1910                          1                              A1
# 2            1899                          1                              A1
# 3            1901                          1                              A1
# 4            1931                          1                              S2
# ...           ...                        ...                             ...
# 23578           0                          4                              V1
# 23579           0                          4                              V1
# 23580        1930                          4                              M1
# 23581        1931                          4                              M1
# 23582        1931                          4                              M1
#
#       saleprice  sale_date
# 0        355000 2013-07-08
# 1        474819 2013-05-20
# 2        210000 2013-03-12
# 3        343116 2013-07-01
# 4             0 2012-08-31
# ...         ...        ...
# 23578         0 2012-12-28
# 23579   2550000 2013-05-16
# 23580    670000 2013-06-11
# 23581         0 2012-12-20
# 23582         0 2012-12-20
#
# [85975 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85975 entries, 0 to 23582
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   borough                         85975 non-null  int64
#  1   district                        85975 non-null  object
#  2   neighborhood                    85975 non-null  object
#  3   building_class_category         85975 non-null  object
#  4   tax_class_at_present            85975 non-null  object
#  5   block                           85975 non-null  int64
#  6   lot                             85975 non-null  int64
#  7   ease_ment                       85975 non-null  object
#  8   building_class_at_present       85975 non-null  object
#  9   address                         85975 non-null  object
#  10  apartmentnumber                 85975 non-null  object
#  11  zip_code                        85975 non-null  int64
#  12  residential_units               85975 non-null  int64
#  13  commercial_units                85975 non-null  int64
#  14  total_units                     85975 non-null  int64
#  15  land_square_feet                85975 non-null  int64
#  16  gross_square_feet               85975 non-null  int64
#  17  year_built                      85975 non-null  int64
#  18  tax_class_at_time_of_sale       85975 non-null  object
#  19  building_class_at_time_of_sale  85975 non-null  object
#  20  saleprice                       85975 non-null  int64
#  21  sale_date                       85975 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(11), object(10)
# memory usage: 15.1+ MB

# %%
houses_on_sale = data[(data.total_units > 0) & (data.land_square_feet > 0)]
houses_on_sale['quantile'] = pd.qcut(houses_on_sale['saleprice'], 10, labels=False, duplicates='drop')
houses_on_sale = houses_on_sale[(houses_on_sale['quantile'] > 0) & (houses_on_sale['quantile'] < 10)].drop(
    columns="quantile")
houses_on_sale['year_quarter'] = houses_on_sale.sale_date.apply(lambda x: f"{x.year}-{x.quarter}")
houses_on_sale
# Out:
# /var/folders/tq/13d3hm697ds01qx5n95rx5fr0000gn/T/ipykernel_10539/1246809621.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   houses_on_sale['quantile'] = pd.qcut(houses_on_sale['saleprice'], 10, labels=False, duplicates='drop')
#        borough district               neighborhood  \
# 0            2    Bronx  BATHGATE
# 1            2    Bronx  BATHGATE
# 2            2    Bronx  BATHGATE
# 3            2    Bronx  BATHGATE
# 5            2    Bronx  BATHGATE
# ...        ...      ...                        ...
# 23571        4   Queens  WOODSIDE
# 23573        4   Queens  WOODSIDE
# 23575        4   Queens  WOODSIDE
# 23576        4   Queens  WOODSIDE
# 23580        4   Queens  WOODSIDE
#
#                             building_class_category tax_class_at_present  \
# 0      01  ONE FAMILY HOMES                                            1
# 1      01  ONE FAMILY HOMES                                            1
# 2      01  ONE FAMILY HOMES                                            1
# 3      01  ONE FAMILY HOMES                                            1
# 5      02  TWO FAMILY HOMES                                            1
# ...                                             ...                  ...
# 23571  29  COMMERCIAL GARAGES                                          4
# 23573  29  COMMERCIAL GARAGES                                          4
# 23575  30  WAREHOUSES                                                  4
# 23576  30  WAREHOUSES                                                  4
# 23580  37  RELIGIOUS FACILITIES                                        4
#
#        block  lot ease_ment building_class_at_present  \
# 0       3028   25                                  A5
# 1       3039   28                                  A1
# 2       3046   39                                  A1
# 3       3046   52                                  A1
# 5       2912  158                                  B1
# ...      ...  ...       ...                       ...
# 23571   1215   43                                  G2
# 23573   2325   40                                  G2
# 23575   1212   63                                  E3
# 23576   1228   48                                  E3
# 23580   1213    6                                  M1
#
#                                          address  ... commercial_units  \
# 0      412 EAST 179TH STREET                      ...                0
# 1      2329 WASHINGTON AVENUE                     ...                0
# 2      2075 BATHGATE AVENUE                       ...                0
# 3      2047 BATHGATE AVENUE                       ...                0
# 5      505 EAST 171ST STREET                      ...                0
# ...                                          ...  ...              ...
# 23571  60-06 37TH   AVENUE                        ...                1
# 23573  64-24 QUEENS BOULEVARD                     ...                1
# 23575  37-19 57TH   STREET                        ...                1
# 23576  57-02 39TH   AVENUE                        ...                1
# 23580  58-11 39TH   AVENUE                        ...                1
#
#        total_units  land_square_feet  gross_square_feet  year_built  \
# 0                1              1842               2048        1901
# 1                1              1103               1290        1910
# 2                1              1986               1344        1899
# 3                1              2329               1431        1901
# 5                2              2000               2400        1993
# ...            ...               ...                ...         ...
# 23571            1             20000              18440        1952
# 23573            1              4000               4000        1939
# 23575            1              5000               4500        1950
# 23576            1             27500               7310        1974
# 23580            1              2523               3000        1930
#
#        tax_class_at_time_of_sale  building_class_at_time_of_sale  saleprice  \
# 0                              1                              A5     355000
# 1                              1                              A1     474819
# 2                              1                              A1     210000
# 3                              1                              A1     343116
# 5                              1                              B1     316500
# ...                          ...                             ...        ...
# 23571                          4                              G2    1850000
# 23573                          4                              G2    1620000
# 23575                          4                              E3       1000
# 23576                          4                              E3    5350000
# 23580                          4                              M1     670000
#
#        sale_date year_quarter
# 0     2013-07-08       2013-3
# 1     2013-05-20       2013-2
# 2     2013-03-12       2013-1
# 3     2013-07-01       2013-3
# 5     2012-12-27       2012-4
# ...          ...          ...
# 23571 2013-04-09       2013-2
# 23573 2013-03-21       2013-1
# 23575 2013-03-05       2013-1
# 23576 2012-09-13       2012-3
# 23580 2013-06-11       2013-2
#
# [25525 rows x 23 columns]

# %%
houses_on_sale['price_per_lsf'] = houses_on_sale.saleprice / houses_on_sale.land_square_feet
houses_on_sale
# Out:
#        borough district               neighborhood  \
# 0            2    Bronx  BATHGATE
# 1            2    Bronx  BATHGATE
# 2            2    Bronx  BATHGATE
# 3            2    Bronx  BATHGATE
# 5            2    Bronx  BATHGATE
# ...        ...      ...                        ...
# 23571        4   Queens  WOODSIDE
# 23573        4   Queens  WOODSIDE
# 23575        4   Queens  WOODSIDE
# 23576        4   Queens  WOODSIDE
# 23580        4   Queens  WOODSIDE
#
#                             building_class_category tax_class_at_present  \
# 0      01  ONE FAMILY HOMES                                            1
# 1      01  ONE FAMILY HOMES                                            1
# 2      01  ONE FAMILY HOMES                                            1
# 3      01  ONE FAMILY HOMES                                            1
# 5      02  TWO FAMILY HOMES                                            1
# ...                                             ...                  ...
# 23571  29  COMMERCIAL GARAGES                                          4
# 23573  29  COMMERCIAL GARAGES                                          4
# 23575  30  WAREHOUSES                                                  4
# 23576  30  WAREHOUSES                                                  4
# 23580  37  RELIGIOUS FACILITIES                                        4
#
#        block  lot ease_ment building_class_at_present  \
# 0       3028   25                                  A5
# 1       3039   28                                  A1
# 2       3046   39                                  A1
# 3       3046   52                                  A1
# 5       2912  158                                  B1
# ...      ...  ...       ...                       ...
# 23571   1215   43                                  G2
# 23573   2325   40                                  G2
# 23575   1212   63                                  E3
# 23576   1228   48                                  E3
# 23580   1213    6                                  M1
#
#                                          address  ... total_units  \
# 0      412 EAST 179TH STREET                      ...           1
# 1      2329 WASHINGTON AVENUE                     ...           1
# 2      2075 BATHGATE AVENUE                       ...           1
# 3      2047 BATHGATE AVENUE                       ...           1
# 5      505 EAST 171ST STREET                      ...           2
# ...                                          ...  ...         ...
# 23571  60-06 37TH   AVENUE                        ...           1
# 23573  64-24 QUEENS BOULEVARD                     ...           1
# 23575  37-19 57TH   STREET                        ...           1
# 23576  57-02 39TH   AVENUE                        ...           1
# 23580  58-11 39TH   AVENUE                        ...           1
#
#        land_square_feet  gross_square_feet  year_built  \
# 0                  1842               2048        1901
# 1                  1103               1290        1910
# 2                  1986               1344        1899
# 3                  2329               1431        1901
# 5                  2000               2400        1993
# ...                 ...                ...         ...
# 23571             20000              18440        1952
# 23573              4000               4000        1939
# 23575              5000               4500        1950
# 23576             27500               7310        1974
# 23580              2523               3000        1930
#
#        tax_class_at_time_of_sale  building_class_at_time_of_sale  saleprice  \
# 0                              1                              A5     355000
# 1                              1                              A1     474819
# 2                              1                              A1     210000
# 3                              1                              A1     343116
# 5                              1                              B1     316500
# ...                          ...                             ...        ...
# 23571                          4                              G2    1850000
# 23573                          4                              G2    1620000
# 23575                          4                              E3       1000
# 23576                          4                              E3    5350000
# 23580                          4                              M1     670000
#
#        sale_date year_quarter price_per_lsf
# 0     2013-07-08       2013-3    192.725299
# 1     2013-05-20       2013-2    430.479601
# 2     2013-03-12       2013-1    105.740181
# 3     2013-07-01       2013-3    147.323315
# 5     2012-12-27       2012-4    158.250000
# ...          ...          ...           ...
# 23571 2013-04-09       2013-2     92.500000
# 23573 2013-03-21       2013-1    405.000000
# 23575 2013-03-05       2013-1      0.200000
# 23576 2012-09-13       2012-3    194.545455
# 23580 2013-06-11       2013-2    265.556877
#
# [25525 rows x 24 columns]

# %%
houses_for_plot = houses_on_sale.drop(
    columns=["sale_date", "address", "zip_code", "block", "lot", "ease_ment", "building_class_at_present",
             "residential_units", "commercial_units", "total_units", "year_built"])
houses_for_plot
# Out:
#        borough district               neighborhood  \
# 0            2    Bronx  BATHGATE
# 1            2    Bronx  BATHGATE
# 2            2    Bronx  BATHGATE
# 3            2    Bronx  BATHGATE
# 5            2    Bronx  BATHGATE
# ...        ...      ...                        ...
# 23571        4   Queens  WOODSIDE
# 23573        4   Queens  WOODSIDE
# 23575        4   Queens  WOODSIDE
# 23576        4   Queens  WOODSIDE
# 23580        4   Queens  WOODSIDE
#
#                             building_class_category tax_class_at_present  \
# 0      01  ONE FAMILY HOMES                                            1
# 1      01  ONE FAMILY HOMES                                            1
# 2      01  ONE FAMILY HOMES                                            1
# 3      01  ONE FAMILY HOMES                                            1
# 5      02  TWO FAMILY HOMES                                            1
# ...                                             ...                  ...
# 23571  29  COMMERCIAL GARAGES                                          4
# 23573  29  COMMERCIAL GARAGES                                          4
# 23575  30  WAREHOUSES                                                  4
# 23576  30  WAREHOUSES                                                  4
# 23580  37  RELIGIOUS FACILITIES                                        4
#
#       apartmentnumber  land_square_feet  gross_square_feet  \
# 0                                  1842               2048
# 1                                  1103               1290
# 2                                  1986               1344
# 3                                  2329               1431
# 5                                  2000               2400
# ...               ...               ...                ...
# 23571                             20000              18440
# 23573                              4000               4000
# 23575                              5000               4500
# 23576                             27500               7310
# 23580                              2523               3000
#
#       tax_class_at_time_of_sale building_class_at_time_of_sale  saleprice  \
# 0                             1                             A5     355000
# 1                             1                             A1     474819
# 2                             1                             A1     210000
# 3                             1                             A1     343116
# 5                             1                             B1     316500
# ...                         ...                            ...        ...
# 23571                         4                             G2    1850000
# 23573                         4                             G2    1620000
# 23575                         4                             E3       1000
# 23576                         4                             E3    5350000
# 23580                         4                             M1     670000
#
#       year_quarter  price_per_lsf
# 0           2013-3     192.725299
# 1           2013-2     430.479601
# 2           2013-1     105.740181
# 3           2013-3     147.323315
# 5           2012-4     158.250000
# ...            ...            ...
# 23571       2013-2      92.500000
# 23573       2013-1     405.000000
# 23575       2013-1       0.200000
# 23576       2012-3     194.545455
# 23580       2013-2     265.556877
#
# [25525 rows x 13 columns]

# %%
houses_by_year = houses_for_plot.groupby(["year_quarter"]).mean()
houses_by_year
# Out:
# /var/folders/tq/13d3hm697ds01qx5n95rx5fr0000gn/T/ipykernel_10539/3462090733.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   houses_by_year = houses_for_plot.groupby(["year_quarter"]).mean()
#                borough  land_square_feet  gross_square_feet     saleprice  \
# year_quarter
# 2012-3        3.385439       4017.789384        8310.827124  1.269311e+06
# 2012-4        3.179438       6483.200790       14012.401579  2.245069e+06
# 2013-1        3.316471       4182.163137       11135.032907  1.290128e+06
# 2013-2        3.377959       4790.296095        8290.570330  1.544683e+06
# 2013-3        3.166070       4405.762757       13745.799463  1.498073e+06
#
#               price_per_lsf
# year_quarter
# 2012-3           630.985097
# 2012-4           488.957560
# 2013-1           313.961102
# 2013-2           371.009507
# 2013-3           371.487912

# %%
houses_by_year.price_per_lsf.plot(kind="bar")
# Out:
# <AxesSubplot: xlabel='year_quarter'>

# %%
houses_by_borough = houses_for_plot.groupby(['district', 'year_quarter'], as_index=False).mean()
houses_by_borough
# Out:
# /var/folders/tq/13d3hm697ds01qx5n95rx5fr0000gn/T/ipykernel_10539/2008691846.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   houses_by_borough = houses_for_plot.groupby(['district', 'year_quarter'], as_index=False).mean()
#          district year_quarter  borough  land_square_feet  gross_square_feet  \
# 0           Bronx       2012-3      2.0       5437.560440        7479.840659
# 1           Bronx       2012-4      2.0      17945.727132       15258.694574
# 2           Bronx       2013-1      2.0       3997.203422        5862.039924
# 3           Bronx       2013-2      2.0      13560.223473        9283.528939
# 4           Bronx       2013-3      2.0       4803.573991        8994.488789
# 5        Brooklyn       2012-3      3.0       3031.502283        4361.619482
# 6        Brooklyn       2012-4      3.0       4161.014547        6110.899578
# 7        Brooklyn       2013-1      3.0       3361.232787        3941.918033
# 8        Brooklyn       2013-2      3.0       2789.536153        4010.380173
# 9        Brooklyn       2013-3      3.0       2970.167785        3616.053691
# 10      Manhattan       2012-3      1.0       5852.088068       56361.545455
# 11      Manhattan       2012-4      1.0       6458.404124       63225.744330
# 12      Manhattan       2013-1      1.0       6553.633613       75722.657143
# 13      Manhattan       2013-2      1.0       5716.061657       58693.138728
# 14      Manhattan       2013-3      1.0       6494.148936       80469.180851
# 15         Queens       2012-3      4.0       3915.175649        3038.542249
# 16         Queens       2012-4      4.0       4279.129427        3850.272766
# 17         Queens       2013-1      4.0       3784.638000        3336.977500
# 18         Queens       2013-2      4.0       3985.031831        3279.256304
# 19         Queens       2013-3      4.0       4157.890123        3280.660494
# 20  Staten Island       2012-3      5.0       4519.078397        2216.975610
# 21  Staten Island       2012-4      5.0      10382.311111        3459.441667
# 22  Staten Island       2013-1      5.0       5472.998688        2084.467192
# 23  Staten Island       2013-2      5.0       5261.964531        2292.805492
# 24  Staten Island       2013-3      5.0       7811.844828        3785.867816
#
#        saleprice  price_per_lsf
# 0   9.977298e+05     168.720658
# 1   1.417980e+06     180.623187
# 2   6.298678e+05     169.752996
# 3   9.304216e+05     187.052718
# 4   1.145668e+06     192.172023
# 5   9.364888e+05    1256.417535
# 6   1.209212e+06     366.124509
# 7   8.713212e+05     298.139228
# 8   9.825486e+05     353.560225
# 9   1.074457e+06     406.401121
# 10  6.822238e+06    1476.155912
# 11  9.787724e+06    1926.319148
# 12  6.637600e+06    1168.783355
# 13  1.026153e+07    1868.009478
# 14  5.649696e+06    1032.806471
# 15  6.364236e+05     187.249937
# 16  8.455086e+05     202.473311
# 17  5.850607e+05     182.611018
# 18  7.152917e+05     199.327332
# 19  7.272527e+05     210.966777
# 20  4.553434e+05     136.002259
# 21  5.009919e+05     136.086449
# 22  4.267413e+05     128.775306
# 23  5.154573e+05     132.048740
# 24  6.232821e+05     127.277499

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax = seaborn.lineplot(data=houses_by_borough, x=houses_by_borough.year_quarter, y=houses_by_borough.price_per_lsf,
                      hue=houses_by_borough.district)
seaborn.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
